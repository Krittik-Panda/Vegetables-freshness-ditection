# %%
import joblib
from features import extract_features

model = joblib.load("lightgbm_vegetable_freshness.pkl")
print("Model Loaded")
# Out:
# Model Loaded

# %%
def predict_image(image_path):

    features = extract_features(image_path)
    features = features.reshape(1, -1)

    prediction = model.predict(features)[0]
    probability = model.predict_proba(features)[0]

    label = "Rotten" if prediction == 1 else "Fresh"

    print("Prediction:", label)
    print("Probability:", probability)

# %%
predict_image("fresh_capsicum.jpg")
# Out:
# Prediction: Fresh
# Probability: [0.96258819 0.03741181]
# c:\Users\KIIT0001\Documents\Mini Project\Vegetables-freshness-ditection\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\KIIT0001\Documents\Mini Project\Vegetables-freshness-ditection\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
